# %% [markdown]
# # 04 — Scenario Prediction
#
# Placeholder notebook. Will train and evaluate `src.models.scenario_clf`,
# report calibration metrics, and demonstrate end-to-end scenario
# probability inference.
